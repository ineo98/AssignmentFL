# %%
# %matplotlib inline
#The line above is necesary to show Matplotlib's plots inside a Jupyter Notebook

from matplotlib import pyplot as plt       
import skimage
import numpy as np 
import cv2

# %%
image = cv2.imread("01.jpg") 
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(img_gray, cmap="gray", vmin=0, vmax=255)

# %%
histr = cv2.calcHist([img_gray],[0],None,[256],[0,256]) 
  
# show the plotting graph of an image 
plt.plot(histr) 
plt.show()

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
mask = cv2.inRange(hsv, (10, 55, 55), (70, 255, 255))
mask_rgb = cv2.cvtColor(mask,cv2.COLOR_GRAY2BGR)

plt.imshow(mask_rgb)

# %%
maskedImg = cv2.cvtColor(cv2.bitwise_and(image, image, mask=mask), cv2.COLOR_BGR2RGB)
plt.imshow(maskedImg)

# %%
mean_rgb = cv2.mean(image, mask)
mean_rgb1
# Out:
# (32.251598806486655, 101.70805007053919, 86.04728829639242, 0.0)
